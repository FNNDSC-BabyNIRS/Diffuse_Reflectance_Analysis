# %%
import numpy as np
from libnirs import *
import pandas as pd
import math
import plotly.graph_objects as go
import matplotlib.pyplot as plt
from matplotlib import ticker, cm
from matplotlib import colors

# %%
dataframe1 = pd.read_excel('Only_LRF_IVH.xlsx')

# %%
dataframe1
# Out:
#     Subject_ID  Date_of_measurement Session Location  \
# 0         B010            2062017.0      S1       LF
# 1         B010            2082017.0      S1       LF
# 2         B010            2102017.0      S1       LF
# 3         B010            2142017.0      S1       LF
# 4         B010            3222017.0      S1       LF
# ..         ...                  ...     ...      ...
# 775       B082            3052020.0      S1       RF
# 776       B085            3132020.0      S1       RF
# 777        NaN                  NaN     NaN      NaN
# 778        NaN                  NaN     NaN      NaN
# 779        NaN                  NaN     NaN      NaN
#
#                    Location_rep    mua673    mua686    mua701    mua724  \
# 0                 1,2,3,4,5,6,7       NaN       NaN       NaN       NaN
# 1                   1,2,3,4,5,6       NaN       NaN       NaN       NaN
# 2    1,10,11,12,2,3,4,5,6,7,8,9  0.143922  0.122859  0.109232  0.099111
# ...
